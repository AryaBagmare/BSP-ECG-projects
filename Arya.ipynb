# %% [markdown]
# <a href="https://colab.research.google.com/github/AryaBagmare/BSP-ECG-projects/blob/main/Arya.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal #filtering, peak detection

# %%
print("hello!!!")
# Out:
# hello!!!

# %% [markdown]
# ## House price Prediction

# %% [markdown]
# file_path = r"C:\Users\HP\OneDrive\Desktop\sidharth.txt\Test.txt"
# data = np.genfromtxt(
#     file_path,
#     skip_header=13,
#     usecols=(0,1),
#     delimiter=None,
#     dtype=float,
#     invalid_raise=False
#
# )
# time=data[:,0]
# ecg = data[:,1]
# ecg = ecg - np.mean(ecg)
#
# print(np.isnan(ecg).sum())
